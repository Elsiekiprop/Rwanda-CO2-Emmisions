# %% [markdown]
# <a href="https://colab.research.google.com/github/Elsiekiprop/Rwanda-CO2-Emmisions/blob/ft-data-cleaning-gikonyo/Predict_CO2_Emissions_in_Rwanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting CO2 Emissions
#
# The ability to accurately monitor carbon emissions is a critical step in the fight against climate change. Precise carbon readings allow researchers and governments to understand the sources and patterns of carbon mass output. While Europe and North America have extensive systems in place to monitor carbon emissions on the ground, there are few available in Africa.
#
# The objective of this challenge is to create a machine learning models using open-source CO2 emissions data from Sentinel-5P satellite observations to predict future carbon emissions.
#
# These solutions may help enable governments, and other actors to estimate carbon emission levels across Africa, even in places where on-the-ground monitoring is not possible.
#
# [Business Understanding](https://docs.google.com/document/d/1KMIqbPeqEkVHFqJONb3H8b8srRi0b6NQp7aDacAXE_Q/edit)

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
# install pycaret to assist with running models
# !pip install pycaret
# import the regression module
from pycaret.regression import *

#Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Functions

# %%
def filter_numerics(df, target_df):
  """
    input: dataframe
    description: the fxn will fill filter the dataframe to give us only int and float values
    output: dataframe with filled values
  """
  for col in df.columns:
    if df[col].dtype in ("int64", "float64"):
      target_df.append(col)
  return target_df

# %%
## Loading the data
from google.colab import drive
drive.mount('/content/drive')

path_var = '/content/drive/MyDrive/Rwanda'
train_df=pd.read_csv(path_var + "/train.csv")
test_df=pd.read_csv(path_var + "/test.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Checking for nature of data
train_df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79023 entries, 0 to 79022
# Data columns (total 69 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      79023 non-null  object
#  1   latitude                                                  79023 non-null  float64
#  2   longitude                                                 79023 non-null  float64
#  3   year                                                      79023 non-null  int64
#  4   week_no                                                   79023 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
# ...

# %% [markdown]
# No categorical data.
# Now lets assess the missing data problem.
# Looking at the results code above, columns containing UVAerosolLayerHeight have majority of the data missing. A solution could be dropping them.

# %%
train_df.drop(columns=['UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_solar_zenith_angle', 'UvAerosolLayerHeight_aerosol_height', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle'], inplace=True)
train_df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24353 entries, 0 to 24352
# Data columns (total 75 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   ID_LAT_LON_YEAR_WEEK                                      24353 non-null  object
#  1   latitude                                                  24353 non-null  float64
#  2   longitude                                                 24353 non-null  float64
#  3   year                                                      24353 non-null  int64
#  4   week_no                                                   24353 non-null  int64
#  5   SulphurDioxide_SO2_column_number_density                  18211 non-null  float64
#  6   SulphurDioxide_SO2_column_number_density_amf              18211 non-null  float64
#  7   SulphurDioxide_SO2_slant_column_number_density            18211 non-null  float64
# ...

# %%
#In the test data it is also evident that the UVAerosolLayerHeight data colums also has a large number of missing data. so we can go ahead and drop the said.
test_df.drop(columns=['UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_solar_zenith_angle', 'UvAerosolLayerHeight_aerosol_height', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle'], inplace=True)
test_df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2022_00     -0.51      29.29  2022        0
# 1  ID_-0.510_29.290_2022_01     -0.51      29.29  2022        1
# 2  ID_-0.510_29.290_2022_02     -0.51      29.29  2022        2
# 3  ID_-0.510_29.290_2022_03     -0.51      29.29  2022        3
# 4  ID_-0.510_29.290_2022_04     -0.51      29.29  2022        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                       NaN
# 1                                  0.000456
# 2                                  0.000161
# 3                                  0.000350
# 4                                 -0.000317
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                           NaN
# 1                                      0.691164
# 2                                      0.605107
# 3                                      0.696917
# 4                                      0.580527
#
# ...

# %%
# We can check for duplicates and drop incase there are any.
train_df_duplicates=train_df[train_df.duplicated()]
train_df.drop_duplicates(inplace=True)
train_df.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
# ...

# %%
train_df.info()

# %% [markdown]
# Looking at the state of the missing values, all columns except 'ID_LAT_LON_YEAR_WEEK', 'longitude', 'latitude',  'year' and 'week_no' have missing values. To deal with them we can fill them up with the mean of each column. This is after considering the nature and types of data for each of these columns.

# %% [markdown]
# # Machine Learning Approach using PyCaret

# %%
numeric_col_df = []
filter_numerics(train_df, numeric_col_df)

# %%
# initialize setup
setup_data = setup(data = train_df, test_data = test_df, target = 'emission', fold_strategy = 'timeseries', numeric_features = numeric_col_df, fold = 3, transform_target = True, session_id = 123, data_split_shuffle=False, fold_shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-b50f286c0dc6> in <cell line: 2>()
#       1 # initialize setup
# ----> 2 setup_data = setup(data = train_df, test_data = test_df, target = 'emission', fold_strategy = 'timeseries', numeric_features = numeric_col_df, fold = 3, transform_target = True, session_id = 123, data_split_shuffle=False, fold_shuffle=False)
#
# ...
